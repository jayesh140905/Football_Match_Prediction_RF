# %%
import pandas as pd

# %%
matches = pd.read_csv("matches.csv", index_col = 0)

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 1  2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away      L  0.0  1.0
# 2  2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home      W  5.0  0.0
# 3  2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home      W  5.0  0.0
# 4  2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away      W  1.0  0.0
# 6  2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home      D  0.0  0.0
#
#          opponent  ...  match report  notes    sh   sot  dist   fk   pk pkatt  \
# 1       Tottenham  ...  Match Report    NaN  18.0   4.0  16.9  1.0  0.0   0.0
# 2    Norwich City  ...  Match Report    NaN  16.0   4.0  17.3  1.0  0.0   0.0
# 3         Arsenal  ...  Match Report    NaN  25.0  10.0  14.3  0.0  0.0   0.0
# 4  Leicester City  ...  Match Report    NaN  25.0   8.0  14.0  0.0  0.0   0.0
# 6     Southampton  ...  Match Report    NaN  16.0   1.0  15.7  1.0  0.0   0.0
#
#    season             team
# 1    2022  Manchester City
# 2    2022  Manchester City
# 3    2022  Manchester City
# 4    2022  Manchester City
# 6    2022  Manchester City
#
# [5 rows x 27 columns]

# %%
matches.shape
# Out:
# (1389, 27)

# %%
no_of_matches_per_season_per_team = 38
no_of_teams = 20
no_of_seasons = 2 #As we have data for two season

total_matches = no_of_matches_per_season_per_team*no_of_teams*no_of_seasons
total_matches
# Out:
# 1520

# %% [markdown]
# This means there's some missing data

# %%
matches["team"].value_counts()  #Matches per team
# Out:
# team
# Manchester United           72
# West Ham United             72
# Newcastle United            72
# Brighton and Hove Albion    72
# Southampton                 72
# Tottenham Hotspur           71
# Manchester City             71
# Leeds United                71
# Wolverhampton Wanderers     71
# Arsenal                     71
# Crystal Palace              71
# Burnley                     71
# Chelsea                     70
# Aston Villa                 70
# Leicester City              70
# Everton                     70
# West Bromwich Albion        38
# Fulham                      38
# Liverpool                   38
# Sheffield United            38
# Brentford                   34
# Norwich City                33
# Watford                     33
# Name: count, dtype: int64

# %% [markdown]
# Since there's a system of relegation, hence the inconsistency in data

# %% [markdown]
# **Cleaning of Data**

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk              float64
# pkatt           float64
# season            int64
# team             object
# dtype: object

# %% [markdown]
# Since we can only work with Numeric Data,

# %%
matches["date"] = pd.to_datetime(matches["date"])

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes
#0 for away games and 1 for home games

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes
matches
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0.0
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5.0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 38 2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L  0.0
# 39 2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L  0.0
# 40 2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W  1.0
# 41 2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L  0.0
# 42 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  1.0
#
#      ga        opponent  ...    sh   sot  dist   fk   pk pkatt season  \
# 1   1.0       Tottenham  ...  18.0   4.0  16.9  1.0  0.0   0.0   2022
# 2   0.0    Norwich City  ...  16.0   4.0  17.3  1.0  0.0   0.0   2022
# 3   0.0         Arsenal  ...  25.0  10.0  14.3  0.0  0.0   0.0   2022
# 4   0.0  Leicester City  ...  25.0   8.0  14.0  0.0  0.0   0.0   2022
# 6   0.0     Southampton  ...  16.0   1.0  15.7  1.0  0.0   0.0   2022
# ..  ...             ...  ...   ...   ...   ...  ...  ...   ...    ...
# 38  4.0       Tottenham  ...   8.0   1.0  17.4  0.0  0.0   0.0   2021
# 39  2.0  Crystal Palace  ...   7.0   0.0  11.4  1.0  0.0   0.0   2021
# 40  0.0         Everton  ...  10.0   3.0  17.0  0.0  0.0   0.0   2021
# 41  1.0   Newcastle Utd  ...  11.0   1.0  16.0  1.0  0.0   0.0   2021
# 42  0.0         Burnley  ...  12.0   3.0  17.0  0.0  0.0   0.0   2021
#
#                 team  venue_code  opp_code
# 1    Manchester City           0        18
# 2    Manchester City           1        15
# 3    Manchester City           1         0
# 4    Manchester City           0        10
# 6    Manchester City           1        17
# ..               ...         ...       ...
# 38  Sheffield United           0        18
# 39  Sheffield United           1         6
# 40  Sheffield United           0         7
# 41  Sheffield United           0        14
# 42  Sheffield United           1         4
#
# [1389 rows x 29 columns]

# %%
matches["hour"] = matches["time"].str.replace(":.+", " ", regex = True).astype("int")

# %%
matches["day_code"] = matches["date"].dt.dayofweek

# %%
matches["target"] = (matches["result"] == "W").astype("int")
#0 for a loss or draw, 1 for a win

# %%
matches
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0.0
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5.0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 38 2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L  0.0
# 39 2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L  0.0
# 40 2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W  1.0
# 41 2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L  0.0
# 42 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  1.0
#
#      ga        opponent  ...   fk   pk  pkatt  season              team  \
# 1   1.0       Tottenham  ...  1.0  0.0    0.0    2022   Manchester City
# 2   0.0    Norwich City  ...  1.0  0.0    0.0    2022   Manchester City
# 3   0.0         Arsenal  ...  0.0  0.0    0.0    2022   Manchester City
# 4   0.0  Leicester City  ...  0.0  0.0    0.0    2022   Manchester City
# 6   0.0     Southampton  ...  1.0  0.0    0.0    2022   Manchester City
# ..  ...             ...  ...  ...  ...    ...     ...               ...
# 38  4.0       Tottenham  ...  0.0  0.0    0.0    2021  Sheffield United
# 39  2.0  Crystal Palace  ...  1.0  0.0    0.0    2021  Sheffield United
# 40  0.0         Everton  ...  0.0  0.0    0.0    2021  Sheffield United
# 41  1.0   Newcastle Utd  ...  1.0  0.0    0.0    2021  Sheffield United
# 42  0.0         Burnley  ...  0.0  0.0    0.0    2021  Sheffield United
#
#    venue_code opp_code hour  day_code  target
# 1           0       18   16         6       0
# 2           1       15   15         5       1
# 3           1        0   12         5       1
# 4           0       10   15         5       1
# 6           1       17   15         5       0
# ..        ...      ...  ...       ...     ...
# 38          0       18   19         6       0
# 39          1        6   15         5       0
# 40          0        7   19         6       1
# 41          0       14   18         2       0
# 42          1        4   16         6       1
#
# [1389 rows x 32 columns]

# %% [markdown]
# **Training the model**

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches["date"] < "2022-01-01"]
test = matches[matches["date"] > "2022-01-01"]

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
predictions = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test["target"], predictions)
acc
# Out:
# 0.6123188405797102

# %%
combined = pd.DataFrame(dict(actual=test["target"], predicted=predictions))

# %%
pd.crosstab(index=combined["actual"], columns=combined["predicted"])
# Out:
# predicted    0   1
# actual
# 0          141  31
# 1           76  28

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["target"], predictions)
# Out:
# 0.4745762711864407

# %%
grouped_matches = matches.groupby("team")
group = grouped_matches.get_group("Chelsea")
group
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2021-08-14  15:00  Premier League   Matchweek 1  Sat  Home      W  3.0
# 2  2021-08-22  16:30  Premier League   Matchweek 2  Sun  Away      W  2.0
# 3  2021-08-28  17:30  Premier League   Matchweek 3  Sat  Away      D  1.0
# 4  2021-09-11  17:30  Premier League   Matchweek 4  Sat  Home      W  3.0
# 6  2021-09-19  16:30  Premier League   Matchweek 5  Sun  Away      W  3.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 51 2021-05-01  17:30  Premier League  Matchweek 34  Sat  Home      W  2.0
# 53 2021-05-08  17:30  Premier League  Matchweek 35  Sat  Away      W  2.0
# 54 2021-05-12  20:15  Premier League  Matchweek 36  Wed  Home      L  0.0
# 56 2021-05-18  20:15  Premier League  Matchweek 37  Tue  Home      W  2.0
# 57 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Away      L  1.0
#
#      ga         opponent  ...   fk   pk  pkatt  season     team venue_code  \
# 1   0.0   Crystal Palace  ...  4.0  0.0    0.0    2022  Chelsea          1
# 2   0.0          Arsenal  ...  0.0  0.0    0.0    2022  Chelsea          0
# 3   1.0        Liverpool  ...  0.0  0.0    0.0    2022  Chelsea          0
# 4   0.0      Aston Villa  ...  0.0  0.0    0.0    2022  Chelsea          1
# 6   0.0        Tottenham  ...  0.0  0.0    0.0    2022  Chelsea          0
# ..  ...              ...  ...  ...  ...    ...     ...      ...        ...
# 51  0.0           Fulham  ...  1.0  0.0    0.0    2021  Chelsea          1
# 53  1.0  Manchester City  ...  1.0  0.0    0.0    2021  Chelsea          0
# 54  1.0          Arsenal  ...  0.0  0.0    0.0    2021  Chelsea          1
# 56  1.0   Leicester City  ...  0.0  1.0    1.0    2021  Chelsea          1
# 57  2.0      Aston Villa  ...  0.0  0.0    0.0    2021  Chelsea          0
#
#    opp_code hour  day_code  target
# 1         6   15         5       1
# 2         0   16         6       1
# 3        11   17         5       0
# 4         1   17         5       1
# 6        18   16         6       1
# ..      ...  ...       ...     ...
# 51        8   17         5       1
# 53       12   17         5       1
# 54        0   20         2       0
# 56       10   20         1       1
# 57        1   16         6       0
#
# [70 rows x 32 columns]

# %%
def rolling_averages(group, cols, new_cols):
  group = group.sort_values("date")
  rolling_stats = group[cols].rolling(3, closed = "left").mean() #Stating that it shouldn't take the current week into consideration
  group[new_cols] = rolling_stats
  group = group.dropna(subset=new_cols)
  return group

# %%
cols = ["gf", "ga", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]
rolling_averages(group, cols, new_cols)
# Out:
#          date   time            comp         round  day venue result   gf  \
# 5  2020-10-03  12:30  Premier League   Matchweek 4  Sat  Home      W  4.0
# 6  2020-10-17  15:00  Premier League   Matchweek 5  Sat  Home      D  3.0
# 8  2020-10-24  17:30  Premier League   Matchweek 6  Sat  Away      D  0.0
# 10 2020-10-31  15:00  Premier League   Matchweek 7  Sat  Away      W  3.0
# 12 2020-11-07  17:30  Premier League   Matchweek 8  Sat  Home      W  4.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 44 2022-03-13  14:00  Premier League  Matchweek 29  Sun  Home      W  1.0
# 47 2022-04-02  15:00  Premier League  Matchweek 31  Sat  Home      L  1.0
# 49 2022-04-09  15:00  Premier League  Matchweek 32  Sat  Away      W  6.0
# 52 2022-04-20  19:45  Premier League  Matchweek 25  Wed  Home      L  2.0
# 53 2022-04-24  14:00  Premier League  Matchweek 34  Sun  Home      W  1.0
#
#      ga        opponent  ...  hour  day_code  target  gf_rolling ga_rolling  \
# 5   0.0  Crystal Palace  ...    12         5       1    2.000000   2.000000
# 6   3.0     Southampton  ...    15         5       0    2.333333   1.666667
# 8   0.0  Manchester Utd  ...    17         5       0    3.333333   2.000000
# 10  0.0         Burnley  ...    15         5       1    2.333333   1.000000
# 12  1.0   Sheffield Utd  ...    17         5       1    2.000000   1.000000
# ..  ...             ...  ...   ...       ...     ...         ...        ...
# 44  0.0   Newcastle Utd  ...    14         6       1    2.666667   0.333333
# 47  4.0       Brentford  ...    15         5       0    2.666667   0.333333
# 49  0.0     Southampton  ...    15         5       1    1.666667   1.666667
# 52  4.0         Arsenal  ...    19         2       0    2.666667   1.333333
# 53  0.0        West Ham  ...    14         6       1    3.000000   2.666667
#
#    sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 5     5.666667    20.366667   0.666667    0.333333       0.666667
# 6     5.666667    18.933333   0.666667    0.666667       1.000000
# 8     6.666667    15.300000   0.666667    0.666667       0.666667
# 10    3.333333    15.300000   0.000000    0.666667       0.666667
# 12    5.000000    15.733333   0.333333    0.000000       0.000000
# ..         ...          ...        ...         ...            ...
# 44    5.000000    15.600000   0.666667    0.000000       0.000000
# 47    5.000000    15.133333   0.666667    0.000000       0.000000
# 49    6.000000    16.100000   0.666667    0.000000       0.000000
# 52    8.333333    17.000000   0.333333    0.000000       0.000000
# 53    8.000000    17.133333   0.000000    0.000000       0.000000
#
# [67 rows x 39 columns]

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
matches_rolling
# Out:
# <ipython-input-124-acb6ae218f4d>:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
#                                  date   time            comp         round  \
# team
# Arsenal                 6  2020-10-04  14:00  Premier League   Matchweek 4
#                         7  2020-10-17  17:30  Premier League   Matchweek 5
#                         9  2020-10-25  19:15  Premier League   Matchweek 6
#                         11 2020-11-01  16:30  Premier League   Matchweek 7
#                         13 2020-11-08  19:15  Premier League   Matchweek 8
# ...                               ...    ...             ...           ...
# Wolverhampton Wanderers 32 2022-03-13  14:00  Premier League  Matchweek 29
#                         33 2022-03-18  20:00  Premier League  Matchweek 30
#                         34 2022-04-02  15:00  Premier League  Matchweek 31
#                         35 2022-04-08  20:00  Premier League  Matchweek 32
#                         36 2022-04-24  14:00  Premier League  Matchweek 34
#
#                             day venue result   gf   ga         opponent  ...  \
# team                                                                     ...
# Arsenal                 6   Sun  Home      W  2.0  1.0    Sheffield Utd  ...
#                         7   Sat  Away      L  0.0  1.0  Manchester City  ...
#                         9   Sun  Home      L  0.0  1.0   Leicester City  ...
#                         11  Sun  Away      W  1.0  0.0   Manchester Utd  ...
#                         13  Sun  Home      L  0.0  3.0      Aston Villa  ...
# ...                         ...   ...    ...  ...  ...              ...  ...
# Wolverhampton Wanderers 32  Sun  Away      W  1.0  0.0          Everton  ...
#                         33  Fri  Home      L  2.0  3.0     Leeds United  ...
#                         34  Sat  Home      W  2.0  1.0      Aston Villa  ...
#                         35  Fri  Away      L  0.0  1.0    Newcastle Utd  ...
#                         36  Sun  Away      L  0.0  1.0          Burnley  ...
#
#                             hour  day_code  target  gf_rolling ga_rolling  \
# team
# Arsenal                 6     14         6       1    2.000000   1.333333
#                         7     17         5       0    1.666667   1.666667
#                         9     19         6       0    1.000000   1.666667
#                         11    16         6       1    0.666667   1.000000
#                         13    19         6       0    0.333333   0.666667
# ...                          ...       ...     ...         ...        ...
# Wolverhampton Wanderers 32    14         6       1    1.333333   1.000000
#                         33    20         4       0    1.666667   0.666667
#                         34    15         5       1    2.333333   1.000000
#                         35    20         4       0    1.666667   1.333333
#                         36    14         6       0    1.333333   1.666667
#
#                            sot_rolling dist_rolling fk_rolling  pk_rolling  \
# team
# Arsenal                 6     3.666667    14.733333   0.666667    0.000000
#                         7     3.666667    15.766667   0.000000    0.000000
#                         9     3.666667    16.733333   0.666667    0.000000
#                         11    4.000000    16.033333   1.000000    0.000000
#                         13    2.666667    18.033333   1.000000    0.333333
# ...                                ...          ...        ...         ...
# Wolverhampton Wanderers 32    3.666667    19.300000   0.000000    0.000000
#                         33    4.333333    19.600000   0.000000    0.000000
#                         34    5.333333    19.833333   0.000000    0.000000
#                         35    5.000000    18.533333   0.000000    0.000000
#                         36    4.666667    17.633333   0.000000    0.000000
#
#                             pkatt_rolling
# team
# Arsenal                 6        0.000000
#                         7        0.000000
#                         9        0.000000
#                         11       0.000000
#                         13       0.333333
# ...                                   ...
# Wolverhampton Wanderers 32       0.000000
#                         33       0.000000
#                         34       0.000000
#                         35       0.000000
#                         36       0.000000
#
# [1317 rows x 39 columns]

# %%
matches_rolling = matches_rolling.droplevel("team")

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
def make_predictons(data, predictors):
  train = data[data["date"] < "2022-01-01"]
  test = data[data["date"] > "2022-01-01"]
  rf.fit(train[predictors], train["target"])
  predictions = rf.predict(test[predictors])
  combined = pd.DataFrame(dict(actual=test["target"], predicted=predictions), index=test.index)
  precision = precision_score(test["target"], predictions)
  return combined, precision

# %%
combined, precision = make_predictons(matches_rolling, predictors + new_cols)
precision
# Out:
# 0.5573770491803278

# %%
combined
# Out:
#       actual  predicted
# 55         0          1
# 56         1          1
# 57         1          0
# 58         1          0
# 59         1          1
# ...      ...        ...
# 1312       1          0
# 1313       0          0
# 1314       1          0
# 1315       0          0
# 1316       0          0
#
# [276 rows x 2 columns]

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)
combined
# Out:
#       actual  predicted       date                     team       opponent  \
# 55         0          1 2022-01-23                  Arsenal        Burnley
# 56         1          1 2022-02-10                  Arsenal         Wolves
# 57         1          0 2022-02-19                  Arsenal      Brentford
# 58         1          0 2022-02-24                  Arsenal         Wolves
# 59         1          1 2022-03-06                  Arsenal        Watford
# ...      ...        ...        ...                      ...            ...
# 1312       1          0 2022-03-13  Wolverhampton Wanderers        Everton
# 1313       0          0 2022-03-18  Wolverhampton Wanderers   Leeds United
# 1314       1          0 2022-04-02  Wolverhampton Wanderers    Aston Villa
# 1315       0          0 2022-04-08  Wolverhampton Wanderers  Newcastle Utd
# 1316       0          0 2022-04-24  Wolverhampton Wanderers        Burnley
#
#      result
# 55        D
# 56        W
# 57        W
# 58        W
# 59        W
# ...     ...
# 1312      W
# 1313      L
# 1314      W
# 1315      L
# 1316      L
#
# [276 rows x 6 columns]

# %%
class MissingDict(dict):
  __missing__ = lambda self, key: key

map_values = {"Brighton and Hove Albion": "Brighton", "Manchester United": "Manchester Utd", "Newcastle United": "Newcastle Utd", "Tottenham Hotspur": "Tottenham", "West Ham United": "West Ham", "Wolverhampton Wanderers": "Wolves"}
mapping = MissingDict(**map_values)

# %%
combined["new_team"] = combined["team"].map(map_values)
combined
# Out:
#       actual  predicted       date                     team       opponent  \
# 55         0          1 2022-01-23                  Arsenal        Burnley
# 56         1          1 2022-02-10                  Arsenal         Wolves
# 57         1          0 2022-02-19                  Arsenal      Brentford
# 58         1          0 2022-02-24                  Arsenal         Wolves
# 59         1          1 2022-03-06                  Arsenal        Watford
# ...      ...        ...        ...                      ...            ...
# 1312       1          0 2022-03-13  Wolverhampton Wanderers        Everton
# 1313       0          0 2022-03-18  Wolverhampton Wanderers   Leeds United
# 1314       1          0 2022-04-02  Wolverhampton Wanderers    Aston Villa
# 1315       0          0 2022-04-08  Wolverhampton Wanderers  Newcastle Utd
# 1316       0          0 2022-04-24  Wolverhampton Wanderers        Burnley
#
#      result new_team
# 55        D      NaN
# 56        W      NaN
# 57        W      NaN
# 58        W      NaN
# 59        W      NaN
# ...     ...      ...
# 1312      W   Wolves
# 1313      L   Wolves
# 1314      W   Wolves
# 1315      L   Wolves
# 1316      L   Wolves
#
# [276 rows x 7 columns]

# %%
merge = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])
merge
# Out:
#     actual_x  predicted_x       date                    team_x  \
# 0          1            0 2022-01-02  Brighton and Hove Albion
# 1          0            0 2022-01-14  Brighton and Hove Albion
# 2          0            1 2022-01-18  Brighton and Hove Albion
# 3          0            0 2022-01-23  Brighton and Hove Albion
# 4          1            0 2022-02-12  Brighton and Hove Albion
# ..       ...          ...        ...                       ...
# 83         1            0 2022-03-13   Wolverhampton Wanderers
# 84         0            0 2022-03-18   Wolverhampton Wanderers
# 85         1            0 2022-04-02   Wolverhampton Wanderers
# 86         0            0 2022-04-08   Wolverhampton Wanderers
# 87         0            0 2022-04-24   Wolverhampton Wanderers
#
#         opponent_x result_x new_team_x  actual_y  predicted_y  \
# 0          Everton        W   Brighton         0            0
# 1   Crystal Palace        D   Brighton         0            0
# 2          Chelsea        D   Brighton         0            0
# 3   Leicester City        D   Brighton         0            0
# 4          Watford        W   Brighton         0            0
# ..             ...      ...        ...       ...          ...
# 83         Everton        W     Wolves         0            1
# 84    Leeds United        L     Wolves         1            0
# 85     Aston Villa        W     Wolves         0            0
# 86   Newcastle Utd        L     Wolves         1            0
# 87         Burnley        L     Wolves         1            0
#
#               team_y opponent_y result_y     new_team_y
# 0            Everton   Brighton        L            NaN
# 1     Crystal Palace   Brighton        D            NaN
# 2            Chelsea   Brighton        D            NaN
# 3     Leicester City   Brighton        D            NaN
# 4            Watford   Brighton        L            NaN
# ..               ...        ...      ...            ...
# 83           Everton     Wolves        L            NaN
# 84      Leeds United     Wolves        W            NaN
# 85       Aston Villa     Wolves        L            NaN
# 86  Newcastle United     Wolves        W  Newcastle Utd
# 87           Burnley     Wolves        W            NaN
#
# [88 rows x 13 columns]

# %%
from sklearn.metrics import accuracy_score, classification_report

# Define predictors
predictors = ["venue_code", "opp_code", "hour", "day_code",
              "gf_rolling", "ga_rolling", "sot_rolling",
              "dist_rolling", "fk_rolling", "pk_rolling", "pkatt_rolling"]

train = matches_rolling[matches_rolling["date"] < "2022-01-01"]
test = matches_rolling[matches_rolling["date"] > "2022-01-01"]

rf = RandomForestClassifier(n_estimators=200, max_depth=10, min_samples_split=5, random_state=1)
rf.fit(train[predictors], train["target"])
predictions = rf.predict(test[predictors])

acc = accuracy_score(test["target"], predictions)
print("Accuracy:", acc*100, "%") #in percentage
# Out:
# Accuracy: 65.21739130434783 %
